# %%
import requests
import pandas as pd
import time
from openpyxl import Workbook

# API URL for fetching live cryptocurrency data
API_URL = "https://api.coingecko.com/api/v3/coins/markets"
PARAMS = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 50,
    "page": 1,
    "sparkline": False
}

def fetch_crypto_data():
    response = requests.get(API_URL, params=PARAMS)
    if response.status_code == 200:
        return response.json()
    else:
        print("Error fetching data", response.status_code)
        return None

def analyze_data(data):
    df = pd.DataFrame(data)[['name', 'symbol', 'current_price', 'market_cap', 'total_volume', 'price_change_percentage_24h']]

    # Top 5 by Market Cap
    top_5 = df.nlargest(5, 'market_cap')

    # Average price of top 50 cryptocurrencies
    avg_price = df['current_price'].mean()

    # Highest and lowest 24-hour price change
    highest_change = df.loc[df['price_change_percentage_24h'].idxmax()]
    lowest_change = df.loc[df['price_change_percentage_24h'].idxmin()]

    return df, top_5, avg_price, highest_change, lowest_change

def update_excel(df):
    filename = "live_crypto_data.xlsx"
    df.to_excel(filename, index=False)
    print(f"Updated {filename} successfully.")

def main():
    while True:
        data = fetch_crypto_data()
        if data:
            df, top_5, avg_price, highest_change, lowest_change = analyze_data(data)
            update_excel(df)
            print("Top 5 by Market Cap:\n", top_5)
            print("Average Price of Top 50 Cryptos: $", avg_price)
            print("Highest 24h Change:", highest_change[['name', 'price_change_percentage_24h']].values)
            print("Lowest 24h Change:", lowest_change[['name', 'price_change_percentage_24h']].values)

        # Update every 5 minutes
        time.sleep(300)

if __name__ == "__main__":
    main()
# Out:
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85864.000000  1701956179928   21112520017
# 1  Ethereum    eth    2230.230000   268732117747   15074707629
# 2    Tether   usdt       0.999631   142365330848   41268935051
# 3       XRP    xrp       2.270000   131193646870    2749616717
# 4       BNB    bnb     607.380000    88487377518     674101190
#
#    price_change_percentage_24h
# 0                      1.63223
# 1                      2.51336
# 2                      0.01060
# 3                      5.34816
# 4                      2.54944
# Average Price of Top 50 Cryptos: $ 5426.967848490601
# Highest 24h Change: ['Hedera' 7.78381]
# Lowest 24h Change: ['Aptos' -4.63949]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85819.000000  1702033818788   20895675158
# 1  Ethereum    eth    2228.930000   268787547236   14695248183
# 2    Tether   usdt       0.999596   142357449681   21379775934
# 3       XRP    xrp       2.270000   131433661728    2633913063
# 4       BNB    bnb     607.010000    88554678334     673667618
#
#    price_change_percentage_24h
# 0                      1.48179
# 1                      2.31797
# 2                      0.00592
# 3                      5.08566
# 4                      2.32384
# Average Price of Top 50 Cryptos: $ 5424.9472217106
# Highest 24h Change: ['Hedera' 7.65831]
# Lowest 24h Change: ['Aptos' -4.76922]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85813.000000  1701781977185   20627888360
# 1  Ethereum    eth    2229.260000   268813544509   14974223717
# 2    Tether   usdt       0.999596   142357436759   26339035166
# 3       XRP    xrp       2.270000   131456700611    2743535951
# 4       BNB    bnb     607.370000    88607477025     670668418
#
#    price_change_percentage_24h
# 0                      1.31600
# 1                      2.19603
# 2                      0.00402
# 3                      5.12005
# 4                      2.33661
# Average Price of Top 50 Cryptos: $ 5424.3167880306
# Highest 24h Change: ['Hedera' 7.76506]
# Lowest 24h Change: ['Aptos' -4.62747]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85799.000000  1701584886548   17327312609
# 1  Ethereum    eth    2228.330000   268708536470   14520351750
# 2    Tether   usdt       0.999603   142358312860   21375568746
# 3       XRP    xrp       2.270000   131500926382    2745623543
# 4       BNB    bnb     607.540000    88633560094     672862236
#
#    price_change_percentage_24h
# 0                      1.28856
# 1                      2.22059
# 2                      0.00470
# 3                      5.13077
# 4                      2.33669
# Average Price of Top 50 Cryptos: $ 5425.1219595105995
# Highest 24h Change: ['Hedera' 7.73373]
# Lowest 24h Change: ['Aptos' -4.51697]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85783.000000  1701175796105   15336715209
# 1  Ethereum    eth    2228.250000   268652406877   14592536562
# 2    Tether   usdt       0.999593   142356940019   25694466695
# 3       XRP    xrp       2.270000   131512742346    2746756665
# 4       BNB    bnb     607.580000    88633560094     666735681
#
#    price_change_percentage_24h
# 0                      1.19252
# 1                      2.17810
# 2                      0.00385
# 3                      4.98525
# 4                      2.18903
# Average Price of Top 50 Cryptos: $ 5422.4447331904
# Highest 24h Change: ['Hedera' 7.5597]
# Lowest 24h Change: ['Aptos' -4.28393]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc     85952.0000  1701175796105   21218517990
# 1  Ethereum    eth      2232.2500   268652406877   14729915136
# 2    Tether   usdt         0.9996   142356940019   40458724192
# 3       XRP    xrp         2.2700   131512742346    2754323710
# 4       BNB    bnb       608.6700    88637833395     675495131
#
#    price_change_percentage_24h
# 0                      1.32249
# 1                      2.24413
# 2                      0.00510
# 3                      4.98131
# 4                      2.21744
# Average Price of Top 50 Cryptos: $ 5429.435105311001
# Highest 24h Change: ['Hedera' 7.4261]
# Lowest 24h Change: ['Aptos' -3.87184]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85950.000000  1704492332261   19975130226
# 1  Ethereum    eth    2231.610000   269100460476   14885438906
# 2    Tether   usdt       0.999595   142357277171   40825777329
# 3       XRP    xrp       2.270000   131827063915    2753946416
# 4       BNB    bnb     608.580000    88801413970     658836182
#
#    price_change_percentage_24h
# 0                      1.37360
# 1                      2.31102
# 2                      0.00191
# 3                      5.12555
# 4                      2.18853
# Average Price of Top 50 Cryptos: $ 5432.3484763108
# Highest 24h Change: ['Hedera' 7.5312]
# Lowest 24h Change: ['Aptos' -3.74083]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85865.000000  1702606606809   20980277697
# 1  Ethereum    eth    2228.640000   268726513548   14890921744
# 2    Tether   usdt       0.999595   142357486446   40735956319
# 3       XRP    xrp       2.270000   131559042191    2748446622
# 4       BNB    bnb     608.060000    88698696433     667556834
#
#    price_change_percentage_24h
# 0                      1.13269
# 1                      2.00692
# 2                      0.00174
# 3                      4.66265
# 4                      1.69187
# Average Price of Top 50 Cryptos: $ 5427.9348430902
# Highest 24h Change: ['Hedera' 7.77907]
# Lowest 24h Change: ['Aptos' -3.86774]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85874.000000  1702930629428   20678108483
# 1  Ethereum    eth    2228.770000   268756680108   14841944533
# 2    Tether   usdt       0.999598   142357464020   38608996469
# 3       XRP    xrp       2.270000   131538799381    2734508975
# 4       BNB    bnb     607.950000    88696994624     667082937
#
#    price_change_percentage_24h
# 0                      1.44938
# 1                      2.36505
# 2                      0.00258
# 3                      5.01272
# 4                      1.85203
# Average Price of Top 50 Cryptos: $ 5428.3847026302
# Highest 24h Change: ['Hedera' 8.25843]
# Lowest 24h Change: ['Aptos' -3.41758]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85857.000000  1702709232017   20364290739
# 1  Ethereum    eth    2227.310000   268593737872   14407072416
# 2    Tether   usdt       0.999598   142357789996   40018938141
# 3       XRP    xrp       2.270000   131339226458    2737973001
# 4       BNB    bnb     607.370000    88612570294     664231849
#
#    price_change_percentage_24h
# 0                      1.52933
# 1                      2.63350
# 2                     -0.00150
# 3                      4.82888
# 4                      1.84650
# Average Price of Top 50 Cryptos: $ 5426.343329569801
# Highest 24h Change: ['Hedera' 8.26661]
# Lowest 24h Change: ['Aptos' -3.05989]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85789.000000  1700999580253   20943288834
# 1  Ethereum    eth    2221.510000   267807053799   14950209401
# 2    Tether   usdt       0.999571   142348751236   40562915856
# 3       XRP    xrp       2.260000   131100856546    2735304786
# 4       BNB    bnb     606.510000    88478678508     660237997
#
#    price_change_percentage_24h
# 0                      1.45606
# 1                      2.60203
# 2                     -0.00743
# 3                      4.77789
# 4                      1.70861
# Average Price of Top 50 Cryptos: $ 5421.0323829692
# Highest 24h Change: ['Hedera' 8.29347]
# Lowest 24h Change: ['Aptos' -2.98117]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85616.000000  1700999580253   20572083571
# 1  Ethereum    eth    2215.780000   267807053799   14793852234
# 2    Tether   usdt       0.999577   142348751236   23265857436
# 3       XRP    xrp       2.260000   131100856546    2734466182
# 4       BNB    bnb     605.550000    88478678508     659276025
#
#    price_change_percentage_24h
# 0                      1.43362
# 1                      2.82506
# 2                     -0.00833
# 3                      5.00686
# 4                      1.76614
# Average Price of Top 50 Cryptos: $ 5411.7594238082
# Highest 24h Change: ['Hedera' 8.59388]
# Lowest 24h Change: ['Aptos' -2.80672]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85676.000000  1699241860542   17841118046
# 1  Ethereum    eth    2216.420000   267256416031   12589366905
# 2    Tether   usdt       0.999597   142357468399   23154681917
# 3       XRP    xrp       2.260000   130759767534    2716492404
# 4       BNB    bnb     606.030000    88415101436     656422590
#
#    price_change_percentage_24h
# 0                      1.51515
# 1                      3.04280
# 2                     -0.00312
# 3                      5.00857
# 4                      1.59514
# Average Price of Top 50 Cryptos: $ 5415.5344570082
# Highest 24h Change: ['Hedera' 8.44422]
# Lowest 24h Change: ['Aptos' -2.68145]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85591.000000  1699241860542   20705343101
# 1  Ethereum    eth    2212.110000   267256416031   13623612412
# 2    Tether   usdt       0.999598   142357468399   37976272807
# 3       XRP    xrp       2.250000   130759767534    2733316570
# 4       BNB    bnb     605.560000    88415101436     654496834
#
#    price_change_percentage_24h
# 0                      1.26937
# 1                      2.76486
# 2                     -0.00366
# 3                      4.81873
# 4                      1.41375
# Average Price of Top 50 Cryptos: $ 5410.987364287999
# Highest 24h Change: ['Hedera' 8.48191]
# Lowest 24h Change: ['Aptos' -2.40501]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85581.000000  1696620548059   19087610851
# 1  Ethereum    eth    2211.050000   266589778644   14156364008
# 2    Tether   usdt       0.999602   142358231977   38825342921
# 3       XRP    xrp       2.250000   130394180135    2741798440
# 4       BNB    bnb     605.850000    88373052918     646600274
#
#    price_change_percentage_24h
# 0                      1.21888
# 1                      2.62386
# 2                     -0.00005
# 3                      4.76206
# 4                      1.64703
# Average Price of Top 50 Cryptos: $ 5407.303542328
# Highest 24h Change: ['Hedera' 8.21324]
# Lowest 24h Change: ['Aptos' -2.20036]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85675.000000  1696620548059   20615773527
# 1  Ethereum    eth    2214.000000   266589778644   14540695345
# 2    Tether   usdt       0.999599   142358231977   38955520670
# 3       XRP    xrp       2.250000   130394180135    2742983571
# 4       BNB    bnb     606.380000    88373052918     641097748
#
#    price_change_percentage_24h
# 0                      1.45764
# 1                      2.89591
# 2                      0.00275
# 3                      5.00270
# 4                      1.79480
# Average Price of Top 50 Cryptos: $ 5413.3179892082
# Highest 24h Change: ['Hedera' 8.953]
# Lowest 24h Change: ['Litecoin' -1.87214]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85637.000000  1698331446861   18814458569
# 1  Ethereum    eth    2212.980000   266853239741   14379633232
# 2    Tether   usdt       0.999591   142356731995   19623714829
# 3       XRP    xrp       2.250000   130621413400    2725215006
# 4       BNB    bnb     606.090000    88420691905     609039212
#
#    price_change_percentage_24h
# 0                      1.51968
# 1                      3.02054
# 2                      0.00133
# 3                      5.34852
# 4                      1.88361
# Average Price of Top 50 Cryptos: $ 5409.8929250480005
# Highest 24h Change: ['Hedera' 9.29978]
# Lowest 24h Change: ['Litecoin' -2.11772]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85634.000000  1697092277021   19601243379
# 1  Ethereum    eth    2212.430000   266504939233   14065279289
# 2    Tether   usdt       0.999601   142357716922   30814128956
# 3       XRP    xrp       2.250000   130394654655    2715030901
# 4       BNB    bnb     605.850000    88329270418     630697651
#
#    price_change_percentage_24h
# 0                      1.45708
# 1                      3.03484
# 2                      0.00103
# 3                      5.61738
# 4                      1.85185
# Average Price of Top 50 Cryptos: $ 5409.697675007602
# Highest 24h Change: ['Hedera' 9.21316]
# Lowest 24h Change: ['Litecoin' -3.11665]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85633.000000  1698046139336   18983052852
# 1  Ethereum    eth    2212.010000   266611876763   14054652031
# 2    Tether   usdt       0.999601   142358149569   23638076486
# 3       XRP    xrp       2.250000   130529150782    2695979392
# 4       BNB    bnb     605.710000    88381923827     600247132
#
#    price_change_percentage_24h
# 0                      1.39882
# 1                      2.87514
# 2                      0.00323
# 3                      5.43832
# 4                      1.75996
# Average Price of Top 50 Cryptos: $ 5410.4185090676
# Highest 24h Change: ['Hedera' 9.63375]
# Lowest 24h Change: ['Litecoin' -3.61597]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85792.000000  1701033004614   21003111439
# 1  Ethereum    eth    2212.700000   266769874414   14085318381
# 2    Tether   usdt       0.999596   142357435789   39818940250
# 3       XRP    xrp       2.260000   130760138364    2695808750
# 4       BNB    bnb     606.650000    88503326613     634048726
#
#    price_change_percentage_24h
# 0                      1.43078
# 1                      2.83194
# 2                      0.00317
# 3                      5.37008
# 4                      1.63572
# Average Price of Top 50 Cryptos: $ 5418.629624827999
# Highest 24h Change: ['Hedera' 8.86635]
# Lowest 24h Change: ['Litecoin' -3.52528]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85670.000000  1699179038172   20934079521
# 1  Ethereum    eth    2206.960000   266225511138   14441013465
# 2    Tether   usdt       0.999584   142355713554   39738840172
# 3       XRP    xrp       2.250000   130558987163    2686201575
# 4       BNB    bnb     605.380000    88299411781     625359774
#
#    price_change_percentage_24h
# 0                      1.11828
# 1                      2.36123
# 2                      0.00427
# 3                      4.97348
# 4                      1.13567
# Average Price of Top 50 Cryptos: $ 5410.053067026601
# Highest 24h Change: ['Hedera' 8.3156]
# Lowest 24h Change: ['Litecoin' -3.90275]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc    85551.00000  1696688392607   18488618350
# 1  Ethereum    eth     2203.41000   265668967551   14032114999
# 2    Tether   usdt        0.99958   142355181135   36315106528
# 3       XRP    xrp        2.25000   130396141982    2682086179
# 4       BNB    bnb      604.89000    88251789347     620276551
#
#    price_change_percentage_24h
# 0                      1.17855
# 1                      2.29753
# 2                      0.00389
# 3                      5.12701
# 4                      1.07554
# Average Price of Top 50 Cryptos: $ 5407.465032206199
# Highest 24h Change: ['Hedera' 8.31859]
# Lowest 24h Change: ['Litecoin' -3.86288]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85276.000000  1691497626992   20988851095
# 1  Ethereum    eth    2191.540000   264541353085   14803216050
# 2    Tether   usdt       0.999585   142355323816   39726066327
# 3       XRP    xrp       2.250000   129882497336    3084505356
# 4       BNB    bnb     602.730000    87981696625     615868386
#
#    price_change_percentage_24h
# 0                      0.92762
# 1                      1.72812
# 2                      0.00621
# 3                      5.02613
# 4                      0.79329
# Average Price of Top 50 Cryptos: $ 5392.503271505
# Highest 24h Change: ['Hedera' 7.8911]
# Lowest 24h Change: ['Litecoin' -4.41437]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85237.000000  1690049665726   18984395561
# 1  Ethereum    eth    2186.590000   263666712591   14693148562
# 2    Tether   usdt       0.999613   142361133148   40028261332
# 3       XRP    xrp       2.240000   129544996607    2703272540
# 4       BNB    bnb     602.040000    87791377250     614427579
#
#    price_change_percentage_24h
# 0                      0.67178
# 1                      1.23921
# 2                      0.00920
# 3                      4.20554
# 4                      0.30835
# Average Price of Top 50 Cryptos: $ 5386.6893714644
# Highest 24h Change: ['Hedera' 7.1431]
# Lowest 24h Change: ['Litecoin' -4.57389]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc    85437.00000  1694332901242   21198714889
# 1  Ethereum    eth     2193.74000   264526612886   14853113390
# 2    Tether   usdt        0.99958   142355614933   38636417131
# 3       XRP    xrp        2.24000   129990556378    2595513432
# 4       BNB    bnb      604.67000    88021943235     477761229
#
#    price_change_percentage_24h
# 0                      1.07011
# 1                      1.69869
# 2                      0.00668
# 3                      4.67539
# 4                      0.90022
# Average Price of Top 50 Cryptos: $ 5398.940327585
# Highest 24h Change: ['Hedera' 7.81595]
# Lowest 24h Change: ['Litecoin' -4.35973]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85469.000000  1694707945303   18627440078
# 1  Ethereum    eth    2192.550000   264388911166   14337998443
# 2    Tether   usdt       0.999572   142353826132   38681615496
# 3       XRP    xrp       2.240000   130010632486    2588807602
# 4       BNB    bnb     604.610000    88194907434     440666689
#
#    price_change_percentage_24h
# 0                      1.24170
# 1                      1.82015
# 2                      0.00401
# 3                      4.92667
# 4                      0.98363
# Average Price of Top 50 Cryptos: $ 5397.709143204801
# Highest 24h Change: ['Hedera' 8.02533]
# Lowest 24h Change: ['Litecoin' -4.18947]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85442.000000  1694914668780   18814945275
# 1  Ethereum    eth    2189.470000   264205904078   14786085217
# 2    Tether   usdt       0.999576   142353863527   33217237321
# 3       XRP    xrp       2.240000   129915660545    2589795384
# 4       BNB    bnb     604.210000    88176400339     448412578
#
#    price_change_percentage_24h
# 0                      1.09523
# 1                      1.58422
# 2                      0.00355
# 3                      4.57910
# 4                      0.79838
# Average Price of Top 50 Cryptos: $ 5394.7986344440005
# Highest 24h Change: ['Hedera' 8.02997]
# Lowest 24h Change: ['Litecoin' -4.4632]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85118.000000  1687940759158   21106740803
# 1  Ethereum    eth    2182.670000   263168024082   14963680655
# 2    Tether   usdt       0.999578   142354863419   23155856447
# 3       XRP    xrp       2.230000   129307931614    2703918782
# 4       BNB    bnb     602.660000    87909102804     474104798
#
#    price_change_percentage_24h
# 0                      0.69680
# 1                      1.13717
# 2                      0.00755
# 3                      4.19283
# 4                      0.50354
# Average Price of Top 50 Cryptos: $ 5373.721204982398
# Highest 24h Change: ['Hedera' 7.7179]
# Lowest 24h Change: ['Litecoin' -4.91033]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85049.000000  1686662007846   21174485711
# 1  Ethereum    eth    2182.290000   263153999450   14806103038
# 2    Tether   usdt       0.999576   142354814218   39227028251
# 3       XRP    xrp       2.230000   129137912757    2705205819
# 4       BNB    bnb     601.880000    87822884058     583493765
#
#    price_change_percentage_24h
# 0                      0.50528
# 1                      1.00042
# 2                      0.00784
# 3                      3.89787
# 4                      0.15409
# Average Price of Top 50 Cryptos: $ 5370.614962321801
# Highest 24h Change: ['Hedera' 7.06272]
# Lowest 24h Change: ['Litecoin' -5.14346]
# Updated live_crypto_data.xlsx successfully.
# Top 5 by Market Cap:
#         name symbol  current_price     market_cap  total_volume  \
# 0   Bitcoin    btc   85230.000000  1690215984323   20547312647
# 1  Ethereum    eth    2188.840000   263942222993   15035399999
# 2    Tether   usdt       0.999571   142353893988   23808297530
# 3       XRP    xrp       2.230000   129312448152    2715462043
# 4       BNB    bnb     602.870000    87947737210     584614670
#
#    price_change_percentage_24h
# 0                      0.66923
# 1                      1.14144
# 2                      0.00738
# 3                      3.92413
# 4                      0.34916
# Average Price of Top 50 Cryptos: $ 5384.5910558222
# Highest 24h Change: ['Hedera' 6.93084]
# Lowest 24h Change: ['Litecoin' -5.06861]
